# %% [markdown]
# ### Team
#
# Phat Panhareach
#
# Cheang Thornsopanha
#
# Leap Chanvuthy
#
# Lim Bunnan Vannuth

# %% [markdown]
# ### Seq2Seq Model Training on Romanization Word to Khmer Word

# %%
import numpy as np
import pandas as pd
from keras.models import Model
from keras.layers import Input, LSTM, Dense
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Load the datasets
data_rom = pd.read_csv("csv/data_rom_500.csv", header=None)  # Romanized text (input)
data_kh = pd.read_csv("csv/data_kh_500.csv", header=None)    # Khmer text (target)

batch_size = 32  # Batch size for training
epochs = 100  # Number of epochs to train for
latent_dim = 256  # Latent dimensionality of the encoding space

# Prepare datasets for Roman-to-Khmer
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()

for input_text in data_rom[0]:  # Romanized text is now the input
    input_text = str(input_text).strip()
    input_texts.append(input_text)
    for char in input_text:
        input_characters.add(char)

for target_text in data_kh[0]:  # Khmer text is now the target
    target_text = '\t' + str(target_text).strip() + '\n'
    target_texts.append(target_text)
    for char in str(target_text):
        target_characters.add(char)

# Sort characters to ensure consistent token indexing
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))

num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)

# Create token indices
input_token_index = {char: i for i, char in enumerate(input_characters)}
target_token_index = {char: i for i, char in enumerate(target_characters)}

# Initialize input and output data for the model
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32")
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32")
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32")

# Populate the data arrays
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # Decoder target data is offset by one timestep
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0

# Define the encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

# Define the decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that combines encoder and decoder
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size=batch_size, epochs=epochs, validation_split=0.2)

# Save the model
model.save("s2s_rom_to_khmer_model_analysis.h5")

# Create inference models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to text
reverse_input_char_index = {i: char for char, i in input_token_index.items()}
reverse_target_char_index = {i: char for char, i in target_token_index.items()}

# Decode sequence function
def decode_sequence(input_seq):
    # Encode the input as state vectors
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Start with the start character
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    decoded_sentence = ""
    stop_condition = False
    while not stop_condition:
        # Predict the next token
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Get the most probable token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Stop condition: end of sequence or max length reached
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update target sequence and states
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0
        states_value = [h, c]

    return decoded_sentence.strip()

# Total and unique words in Khmer and Romanized datasets
total_rom_words = sum(len(str(text).split()) for text in data_rom[0])
unique_rom_words = len(set(word for text in data_rom[0] for word in str(text).split()))

total_kh_words = sum(len(str(text).split()) for text in data_kh[0])
unique_kh_words = len(set(word for text in data_kh[0] for word in str(text).split()))

print(f"Total Romanized words: {total_rom_words}")
print(f"Unique Romanized words: {unique_rom_words}")
print(f"Total Khmer words: {total_kh_words}")
print(f"Unique Khmer words: {unique_kh_words}")

# Plot word density
rom_word_lengths = [len(str(text).split()) for text in data_rom[0]]
kh_word_lengths = [len(str(text).split()) for text in data_kh[0]]

plt.figure(figsize=(12, 6))
sns.kdeplot(rom_word_lengths, label='Romanized Word Lengths', fill=True)
sns.kdeplot(kh_word_lengths, label='Khmer Word Lengths', fill=True, warn_singular=False)
plt.title('Word Length Density')
plt.xlabel('Word Length')
plt.ylabel('Density')
plt.legend()
plt.show()

# Generate word cloud for Romanized text
plt.figure(figsize=(12, 8))
wc_rom = WordCloud(width=600, height=300).generate(' '.join(input_texts))
plt.imshow(wc_rom, interpolation='bilinear')
plt.title('Word Cloud for Romanized Text')
plt.axis('off')
plt.show()

# Generate word cloud for Khmer text
plt.figure(figsize=(12, 8))
wc_kh = WordCloud(width=600, height=300, font_path='fonts/Taprom.ttf').generate(' '.join(target_texts))
plt.imshow(wc_kh, interpolation='bilinear')
plt.title('Word Cloud for Khmer Text')
plt.axis('off')
plt.show()

# Model summary
model.summary()

# Plot loss graph
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot accuracy graph
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Test the model on some inputs and calculate BLEU score
for seq_index in range(10):  # Test on first 10 samples
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)

    # Get ground truth and remove start/end tokens
    reference = list(target_texts[seq_index].strip("\t\n"))
    hypothesis = list(decoded_sentence)

    # Calculate BLEU score

    print(f"Romanized word: {input_texts[seq_index]}")
    print(f"Khmer word: {''.join(reference)}")
    print(f"Predicted Khmer: {decoded_sentence}")
# Out:
# Number of samples: 500
# Number of unique input tokens: 23
# Number of unique output tokens: 68
# Max sequence length for inputs: 20
# Max sequence length for outputs: 13
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.0671 - loss: 1.5561 - val_accuracy: 0.0746 - val_loss: 1.7189
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.0802 - loss: 1.3285 - val_accuracy: 0.0785 - val_loss: 1.5845
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.0929 - loss: 1.2800 - val_accuracy: 0.1085 - val_loss: 1.5808
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.1000 - loss: 1.2708 - val_accuracy: 0.0962 - val_loss: 1.5711
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.0990 - loss: 1.2659 - val_accuracy: 0.1085 - val_loss: 1.5589
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.1006 - loss: 1.2618 - val_accuracy: 0.1085 - val_loss: 1.5490
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.0967 - loss: 1.2582 - val_accuracy: 0.1085 - val_loss: 1.5537
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.1002 - loss: 1.2590 - val_accuracy: 0.1085 - val_loss: 1.5398
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.1000 - loss: 1.2522 - val_accuracy: 0.1062 - val_loss: 1.5447
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.0988 - loss: 1.2514 - val_accuracy: 0.1085 - val_loss: 1.5227
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.1006 - loss: 1.2464 - val_accuracy: 0.1085 - val_loss: 1.5271
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.1004 - loss: 1.2441 - val_accuracy: 0.1108 - val_loss: 1.5195
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.1008 - loss: 1.2431 - val_accuracy: 0.0977 - val_loss: 1.5348
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.0998 - loss: 1.2404 - val_accuracy: 0.1069 - val_loss: 1.5271
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.1004 - loss: 1.2391 - val_accuracy: 0.1069 - val_loss: 1.5373
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.1000 - loss: 1.2336 - val_accuracy: 0.1054 - val_loss: 1.5260
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.0979 - loss: 1.2386 - val_accuracy: 0.1077 - val_loss: 1.5213
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step - accuracy: 0.1010 - loss: 1.2332 - val_accuracy: 0.1077 - val_loss: 1.5124
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.1027 - loss: 1.2257 - val_accuracy: 0.1031 - val_loss: 1.5315
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.1000 - loss: 1.2360 - val_accuracy: 0.1185 - val_loss: 1.5203
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.1031 - loss: 1.2259 - val_accuracy: 0.1038 - val_loss: 1.5268
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.1021 - loss: 1.2252 - val_accuracy: 0.1108 - val_loss: 1.5081
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.1338 - loss: 1.1262 - val_accuracy: 0.1385 - val_loss: 1.4460
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.1338 - loss: 1.1213 - val_accuracy: 0.1392 - val_loss: 1.4443
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - accuracy: 0.1338 - loss: 1.1245 - val_accuracy: 0.1385 - val_loss: 1.4357
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.1354 - loss: 1.1188 - val_accuracy: 0.1262 - val_loss: 1.4787
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 181ms/step - accuracy: 0.1350 - loss: 1.1224 - val_accuracy: 0.1300 - val_loss: 1.4633
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step - accuracy: 0.1360 - loss: 1.1185 - val_accuracy: 0.1377 - val_loss: 1.4519
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - accuracy: 0.1363 - loss: 1.1170 - val_accuracy: 0.1338 - val_loss: 1.4418
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.1383 - loss: 1.1128 - val_accuracy: 0.1408 - val_loss: 1.4372
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.1367 - loss: 1.1126 - val_accuracy: 0.1392 - val_loss: 1.4423
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.1367 - loss: 1.1107 - val_accuracy: 0.1408 - val_loss: 1.4491
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - accuracy: 0.1379 - loss: 1.1088 - val_accuracy: 0.1354 - val_loss: 1.4439
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.1367 - loss: 1.1098 - val_accuracy: 0.1362 - val_loss: 1.4582
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.1365 - loss: 1.1115 - val_accuracy: 0.1369 - val_loss: 1.4421
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - accuracy: 0.1363 - loss: 1.1077 - val_accuracy: 0.1369 - val_loss: 1.4433
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.1394 - loss: 1.1058 - val_accuracy: 0.1377 - val_loss: 1.4386
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - accuracy: 0.1388 - loss: 1.1008 - val_accuracy: 0.1369 - val_loss: 1.4448
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - accuracy: 0.1398 - loss: 1.1009 - val_accuracy: 0.1400 - val_loss: 1.4413
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 188ms/step - accuracy: 0.1408 - loss: 1.0983 - val_accuracy: 0.1338 - val_loss: 1.4453
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Total Romanized words: 519
# Unique Romanized words: 459
# Total Khmer words: 500
# Unique Khmer words: 500
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, None, 23)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None, 68)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 256),     │    286,720 │ input_layer[0][0] │
# │                     │ (None, 256),      │            │                   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, None,     │    332,800 │ input_layer_1[0]… │
# │                     │ 256), (None,      │            │ lstm[0][1],       │
# │                     │ 256), (None,      │            │ lstm[0][2]        │
# │                     │ 256)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, None, 68)  │     17,476 │ lstm_1[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,273,994 (4.86 MB)
#  Trainable params: 636,996 (2.43 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 636,998 (2.43 MB)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Romanized word: ban
# Khmer word: បាន
# Predicted Khmer: ប្
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Romanized word: kar
# Khmer word: ការ
# Predicted Khmer: ក្
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Romanized word: mean
# Khmer word: មាន
# Predicted Khmer: អ្
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Romanized word: chea
# Khmer word: ជា
# Predicted Khmer: ច្
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Romanized word: now
# Khmer word: នៅ
# Predicted Khmer: នន
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Romanized word: ning
# Khmer word: និង
# Predicted Khmer: នន
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Romanized word: del
# Khmer word: ដែល
# Predicted Khmer: ដ្
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Romanized word: knong
# Khmer word: ក្នុង
# Predicted Khmer: កក
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Romanized word: nih
# Khmer word: នេះ
# Predicted Khmer: ពិ
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Romanized word: tha
# Khmer word: ថា
# Predicted Khmer: ទ្
